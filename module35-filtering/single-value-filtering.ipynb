# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
data = pd.read_csv('complications.csv')

# %%
data.describe()
# Out:
#            ZIP Code  Phone Number
# count  92383.000000  9.238300e+04
# mean   54006.137590  5.846386e+09
# std    26950.784084  2.333757e+09
# min      603.000000  9.369338e+08
# 25%    32932.000000  3.867199e+09
# 50%    55404.000000  6.053347e+09
# 75%    76092.000000  7.877572e+09
# max    99929.000000  9.898943e+09

# %%
data.head()
# Out:
#   Provider ID                      Hospital Name                Address  \
# 0      050616  ST JOHNS PLEASANT VALLEY HOSPITAL       2309 ANTONIO AVE
# 1      060071     DELTA COUNTY MEMORIAL HOSPITAL      1501 E 3RD STREET
# 2      070033                   DANBURY HOSPITAL        24 HOSPITAL AVE
# 3      100175           DESOTO MEMORIAL HOSPITAL       900 N ROBERT AVE
# 4      140083                   LORETTO HOSPITAL  645 SOUTH CENTRAL AVE
#
#         City State  ZIP Code County Name  Phone Number  \
# 0  CAMARILLO    CA     93010     VENTURA    8053895800
# 1      DELTA    CO     81416       DELTA    9708747681
# 2    DANBURY    CT      6810   FAIRFIELD    2037397000
# 3    ARCADIA    FL     34265     DE SOTO    8634943535
# 4    CHICAGO    IL     60644        COOK    7736264300
#
#                      Measure Name   Measure ID  \
# 0                  Pressure sores  PSI_3_ULCER
# 1                  Pressure sores  PSI_3_ULCER
# 2  Death rate for stroke patients  MORT_30_STK
# ...

# %%
filter = data['State'] == 'CA'

# %%
filter.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: State, dtype: bool

# %%
ca_only = data[filter]

# %%
ca_only.head()
# Out:
#      Provider ID                      Hospital Name               Address  \
# 0         050616  ST JOHNS PLEASANT VALLEY HOSPITAL      2309 ANTONIO AVE
# 2513      050039               ENLOE MEDICAL CENTER        1531 ESPLANADE
# 2565      050002                   ST ROSE HOSPITAL    27200 CALAROGA AVE
# 2702      050069                 ST JOSEPH HOSPITAL  1100 WEST STEWART DR
# 2956      050069                 ST JOSEPH HOSPITAL  1100 WEST STEWART DR
#
#            City State  ZIP Code County Name  Phone Number  \
# 0     CAMARILLO    CA     93010     VENTURA    8053895800
# 2513      CHICO    CA     95926       BUTTE    5303327300
# 2565    HAYWARD    CA     94545     ALAMEDA    5107826200
# 2702     ORANGE    CA     92868      ORANGE    7146339111
# 2956     ORANGE    CA     92868      ORANGE    7146339111
#
#                                  Measure Name     Measure ID  \
# 0                              Pressure sores    PSI_3_ULCER
# ...

# %% [markdown]
# # RegEx Filtering

# %%
med_center_filter = data['Hospital Name'].str.contains('CENTER$')
med_centers = data[med_center_filter]

# %%
med_centers.shape
# Out:
# (24899, 19)

# %%
hospital_filter = data['Hospital Name'].str.contains('HOSPITAL')
hospitals = data[hospital_filter]

# %%
hospitals.shape
# Out:
# (52668, 19)

# %%
valid_addr = data['Address'].str.contains('[0-9]{1,6} [A-Z0-9 ]+')

# %%
invalid = data[~valid_addr]

# %%
invalid.head()
# Out:
#      Provider ID                       Hospital Name              Address  \
# 36        670004             ST MARKS MEDICAL CENTER  ONE ST MARK'S PLACE
# 1038      021301    PROVIDENCE VALDEZ MEDICAL CENTER           PO BOX 550
# 1048      020018  YUKON KUSKOKWIM DELTA REG HOSPITAL           PO BOX 287
# 1054      021304           PETERSBURG MEDICAL CENTER           PO BOX 589
# 1057      010131            CRESTWOOD MEDICAL CENTER   ONE HOSPITAL DR SE
#
#             City State  ZIP Code County Name  Phone Number  \
# 36     LA GRANGE    TX     78945     FAYETTE    9792422200
# 1038      VALDEZ    AK     99686         NaN    9078352249
# 1048      BETHEL    AK     99559      BETHEL    9075436300
# 1054  PETERSBURG    AK     99833         NaN    9077724291
# 1057  HUNTSVILLE    AL     35801     MADISON    2568823100
#
#                                Measure Name    Measure ID  \
# 36                           Pressure sores   PSI_3_ULCER
# ...

# %%
data[valid_addr].head()
# Out:
#   Provider ID                      Hospital Name                Address  \
# 0      050616  ST JOHNS PLEASANT VALLEY HOSPITAL       2309 ANTONIO AVE
# 1      060071     DELTA COUNTY MEMORIAL HOSPITAL      1501 E 3RD STREET
# 2      070033                   DANBURY HOSPITAL        24 HOSPITAL AVE
# 3      100175           DESOTO MEMORIAL HOSPITAL       900 N ROBERT AVE
# 4      140083                   LORETTO HOSPITAL  645 SOUTH CENTRAL AVE
#
#         City State  ZIP Code County Name  Phone Number  \
# 0  CAMARILLO    CA     93010     VENTURA    8053895800
# 1      DELTA    CO     81416       DELTA    9708747681
# 2    DANBURY    CT      6810   FAIRFIELD    2037397000
# 3    ARCADIA    FL     34265     DE SOTO    8634943535
# 4    CHICAGO    IL     60644        COOK    7736264300
#
#                      Measure Name   Measure ID  \
# 0                  Pressure sores  PSI_3_ULCER
# 1                  Pressure sores  PSI_3_ULCER
# 2  Death rate for stroke patients  MORT_30_STK
# ...
